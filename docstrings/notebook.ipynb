# %% [markdown]
# #### Lessons learnt while trying to automate docstring testing - Saurabh Hirani
#
# Original blog post link for comments: http://curiosityhealsthecat.blogspot.in/2014/02/lessons-learnt-while-automating.html

# %% [markdown]
# The aim of this post is describe the evolution of a program which automates docstring testing of a module and its components (functions, classes, nested classes and their respective methods). It starts out simple and as we keep on noticing limitations - we keep on making incremental changes to address those limitations.
#
# Although I am using an ipython notebook, I don't want the end user to copy paste and run the cell source code to try the code examples outside of the notebook. So I am using the %load ipython magic to load the source files from my ipython directory instead of typing code directly in the cells. These files map to the supporting github repo of this post - https://github.com/saurabh-hirani/talks/tree/master/docstrings - So to use code separately, clone this repo and you are good to run t1.py, t2.py and so on. Read from here, play from there.
#
# For the sake of simplicity, let us assume that the module which we want to test for docstrings has the  structure defined in __mod1.py__:

# %% [markdown]
# %load mod1.py

# %%
class SpecFile(object):
    class Section(object):
        def __init__(self): pass
        def validate(self): pass
        
    class DynamicSection(Section):
        def __init__(self): pass
        
    class StaticSection(Section):
        def __init__(self): pass
        
    class Section1(StaticSection):
        def validate(self): pass
        
    class Section2(DynamicSection):
        def validate(self): pass
        
def main():
    pass

# %% [markdown]
# This represents the structure of a spec file which contains various sections. Some sections have static i.e. pre-defined keys and some have dynamic keys i.e. key-value pairs that are not known in advance. Section1 and Section2 are just instances of 2 such sections. The main function is called when user executes the program from the cmdline. We are not concerned with the internal logic as I am trying to automate docstring testing.
#
# nbcommon.py contains all the common operations.

# %% [raw]
# %load nbcommon.py

# %%
# custom exception class for no docstring
class NoDocstrError(Exception): pass

def has_docstr(entity):
    """ Check whether this entity has a docstring """
    docstr = entity.__doc__
    return docstr != None and docstr.strip() != ''

import inspect

def get_entity_type(entity):
    """ Check whether entity is supported for docstring check """
    for entity_type in ['module', 'function', 'class', 'method'] :
        # inspect module has inspect.ismodule, inspect.isfunction - leverage that
        inspect_func = getattr(inspect, 'is' + entity_type)
        if inspect_func(entity): return entity_type
    raise ValueError('Invalid entity: %s passed' % entity)

# %% [markdown]
# inspect module is used to get the members of an entity (a class, module, etc.) By using get_entity_type we are just saying that while getting the members of a module - we will perform docstring tests on only the ones which are supported by this function.

# %% [markdown]
# I don't know how to run a py.test code in a notebook. So to keep things simple, I will use self contained examples to test for docstrings.
#
# Also because ipython notebook does not support namespaces as far as I know, I will use classes like TestDocstr1, TestDocstr2, etc. to show the evolution of code.
#
# For the first cut, we will use the code in __t1.py__ which does a simple docstring test.

# %% [raw]
# %load t1.py

# %%
from nbcommon import *
import mod1

class TestDocstr1(object):
    """ Test whether the passed entity has a docstring """
    def test_docstr(self, entity):
        if not has_docstr(entity):
            raise NoDocstrError("%s does not have docstr" % entity.__name__)
        return True
        
t1 = TestDocstr1()
t1.test_docstr(mod1)
t1.test_docstr(mod1.SpecFile)
t1.test_docstr(mod1.SpecFile.Section)
t1.test_docstr(mod1.SpecFile.DynamicSection)
t1.test_docstr(mod1.SpecFile.StaticSection)
t1.test_docstr(mod1.SpecFile.Section1)
t1.test_docstr(mod1.SpecFile.Section2)
t1.test_docstr(mod1.main)
# Out:
# ---------------------------------------------------------------------------
# NoDocstrError                             Traceback (most recent call last)
# <ipython-input-3-6a592c9f5516> in <module>()
#      10
#      11 t1 = TestDocstr1()
# ---> 12 t1.test_docstr(mod1)
#      13 t1.test_docstr(mod1.SpecFile)
#      14 t1.test_docstr(mod1.SpecFile.Section)
#
# <ipython-input-3-6a592c9f5516> in test_docstr(self, entity)
#       6     def test_docstr(self, entity):
#       7         if not has_docstr(entity):
# ----> 8             raise NoDocstrError("%s does not have docstr" % entity.__name__)
#       9         return True
#      10
#
# NoDocstrError: mod1 does not have docstr

# %% [markdown]
# __t1.py__ has the following limitations:
#
# 1. I have to run test_docstr for each element - even though I know that all elements are nested under mod1 module.
# 2. The solution does not specify the element type - i.e. error messages should be prefixed with the entity type - "Class SpecFile does not have a docstr" or "Module mod1 does not have docstr".
# 3. We don't get all the errors i.e. we should be covering all elements and then printing a consolidated list of docstring-less elements.
#
# So in order to address these limitations we need to:
#
# 1. Use the inspect module to get members of the passed entity.
# 2. For each member test whether it has a docstring - if it doesn't - keep on storing the errors and spit out a consolidated list to the end user.

# %% [markdown]
# Using the above pointers, we evolve __t1.py__ to __t2.py__ :

# %% [raw]
# %load t2.py

# %%
from nbcommon import *
import mod1

import inspect
from collections import defaultdict

class TestDocstr2(object):
    def test_docstr(self, entity):
        """ Test whether the passed in entity and its children have docstring """
        entity_type = None
        non_docstr_entities = defaultdict(list)

        # get all the members of the passed entity
        for member in inspect.getmembers(entity):
            ref = member[1]
            try:
                entity_type = get_entity_type(ref)
                if not has_docstr(ref):
                    non_docstr_entities[entity_type].append(ref)
            except ValueError:
                # invalid entity type - skip it
                continue

        # if any entities without docstring - consolidate and raise error
        if non_docstr_entities.keys():
            errors = []
            for entity_type, refs in non_docstr_entities.iteritems():
                for ref in refs:
                    errors.append('%s %s does not have docstr' % (entity_type,
                                                                  ref.__name__))
            raise NoDocstrError('\n'.join(errors))

        return True

t2 = TestDocstr2()

print "testing mod1"
print "-----------"
try:
    t2.test_docstr(mod1)
except NoDocstrError as e:
    print e
print "-----------"

print "\ntesting mod1.SpecFile"
print "-----------"
try:
    t2.test_docstr(mod1.SpecFile)
except NoDocstrError as e:
    print e
print "-----------"
# Out:
# testing mod1
# -----------
# function main does not have docstr
# class SpecFile does not have docstr
# -----------
#
# testing mod1.SpecFile
# -----------
# class DynamicSection does not have docstr
# class Section does not have docstr
# class Section1 does not have docstr
# class Section2 does not have docstr
# class StaticSection does not have docstr
# -----------

# %% [markdown]
# The above code tests the first level children of mod1 i.e. the function main and the class SpecFile. It does not:
#
# 1. Test the mod1 module itself.
# 2. It does not check the methods defined in SpecFile.
#
# Also while testing mod1.SpecFile, it tests the classes in SpecFile but not the methods of SpecFile and neither the methods in any of the classes in mod1.SpecFile.

# %% [markdown]
# Hence __t2.py__ has the following limitations:
#
# 1. Top level entities are not traversed i.e. when a module is passed the code does not traverse through all the classes defined in it, when a class is passed the code does not traverse through the methods defined it in it.
#
# To overcome the above limitation, we do the following:
#
# 1. As soon as you get a member - check if it is a member which can nest other members. In our code a module can nest - class, functions. A class can nest - methods, classes.
#
# An additional check we can do at this stage is to filter out only those members which are defined in this module i.e. if someone does a  'from docopt import \*' we don't want to test the members which polluted the module name space. We will also change the object instantiation to pass in the entity during object creation stage itself.

# %% [markdown]
# Using the above pointers, we can evolve __t2.py__ to __t3.py__:

# %% [raw]
# %load t3.py

# %%
from nbcommon import *
import mod1

import inspect
import sys
from collections import defaultdict

class TestDocstr3(object):

    # update __init__ to load entity at startup as there a few more
    # params being initialized 
    def __init__(self, base_entity):
        self.base_entity_type = get_entity_type(base_entity)
        self.base_entity = base_entity
        self.base_module = base_entity
        if self.base_entity_type != 'module':
            # if entity_type is class - know which module it belongs to
            self.base_module = sys.modules[base_entity.__module__]

    def get_entity_members(self, entity):
        """ Get first level members of the passed entity """
        members = []
        for member in inspect.getmembers(entity):
            ref = member[1]
            # member has to be of supported entity type
            try:
                ref_type = get_entity_type(ref)
            except ValueError:
                continue
            # member has to be defined in base module
            if ref.__module__ != self.base_module.__name__: continue
            # valid member - append member reference and type to the member 
            # list
            members.append((ref_type, ref))
        return members

    def get_all_members(self):
        """ Get all the members (nested also) of the passed entity """
        all_members = [(self.base_entity_type, self.base_entity)]
        # get first level members of the main entity
        nested_members = self.get_entity_members(self.base_entity)
        all_members.extend(nested_members)

        # call get_entity_members repetitively till you reach a stage where 
        # there are no nested members
        while nested_members:
            curr_nested_members = []
            for member_type, member_ref in nested_members:
                if member_type == 'class':
                    # drill nested members only in a class
                    members = self.get_entity_members(member_ref)
                    curr_nested_members.extend(members)
            nested_members = curr_nested_members
            all_members.extend(nested_members)

        return all_members

    def test_docstr(self):

        non_docstr_entities = defaultdict(list)

        # get all the nested members of root entity
        for member_type, member_ref in self.get_all_members():
            # consolidate members based on type
            if not has_docstr(member_ref):
                non_docstr_entities[member_type].append(member_ref)

        if non_docstr_entities.keys():
            errors = []
            # create error string
            for entity_type, refs in non_docstr_entities.iteritems():
                for ref in refs:
                    errors.append('%s: %s does not have docstr' % (entity_type,
                                                                ref.__name__))
            raise NoDocstrError('\n' + '\n'.join(errors))

        return True

t3 = TestDocstr3(mod1)
t3.test_docstr()
# Out:
# ---------------------------------------------------------------------------
# NoDocstrError                             Traceback (most recent call last)
# <ipython-input-5-d4163eebd782> in <module>()
#      78
#      79 t3 = TestDocstr3(mod1)
# ---> 80 t3.test_docstr()
#
# <ipython-input-5-d4163eebd782> in test_docstr(self)
#      73                     errors.append('%s: %s does not have docstr' % (entity_type,
#      74                                                                 ref.__name__))
# ---> 75             raise NoDocstrError('\n' + '\n'.join(errors))
#      76
#      77         return True
#
# NoDocstrError:
# function: main does not have docstr
# class: SpecFile does not have docstr
# class: DynamicSection does not have docstr
# class: Section does not have docstr
# class: Section1 does not have docstr
# class: Section2 does not have docstr
# class: StaticSection does not have docstr
# module: mod1 does not have docstr
# method: __init__ does not have docstr
# method: validate does not have docstr
# method: __init__ does not have docstr
# method: validate does not have docstr
# method: __init__ does not have docstr
# method: validate does not have docstr
# method: __init__ does not have docstr
# method: validate does not have docstr
# method: __init__ does not have docstr
# method: validate does not have docstr

# %% [markdown]
# As you can see from the above run of __t3.py__ - by passing in a module - we are able to test all the nested members inside the module. Same goes for a class. Even then, there are some glaring limitations of the above solution:
#
# 1. The names are not fully qualified. The string "method: validate does not have docstr" - but validate method is defined in multiple classes - Section, Section1, Section2, etc.
# 2. The process of getting members of an entity and testing them for docstrings should be decoupled from each other.
#
# __t4.py__ tries to address these limitations by doing the following:
#
# 1. Decouple ModStruct1 (class for getting all members of an entity) from TestDocstr4.
# 2. In ModStruct1.get\_members call we prepend the member name by its parent. i.e. did  entity.\_\_name\_\_ + '.' + ref.\_\_name\_\_ and used this name later.
# 3. Made test_docstr a class method.

# %% [raw]
# %load t4.py

# %%
from nbcommon import *
import mod1

import inspect
import sys
from collections import defaultdict

class ModStruct1(object):
    """ Return a data structure representing all members of the passed
    entity """

    def __init__(self, base_entity):
        self.base_entity_type = get_entity_type(base_entity)
        self.base_entity = base_entity
        self.base_module = base_entity
        if self.base_entity_type != 'module':
            # if entity_type is class - know which module it belongs to
            self.base_module = sys.modules[base_entity.__module__]

    def get_entity_members(self, entity):
        """ Get first level members of the passed entity """
        members = []
        for member in inspect.getmembers(entity):
            ref = member[1]
            # member has to be of supported entity type
            try:
                ref_type = get_entity_type(ref)
            except ValueError:
                continue
            # member has to be defined in base module
            if ref.__module__ != self.base_module.__name__: continue
            # valid member - append member reference, type and name to the 
            # member  list
            members.append((ref_type, ref, 
                            entity.__name__ + '.' + ref.__name__))
        return members

    def get_all_members(self):
        """ Get all the members (nested also) of the passed entity """
        all_members = [(self.base_entity_type, self.base_entity, 
                        self.base_entity.__name__)]
        # get first level members of the main entity
        nested_members = self.get_entity_members(self.base_entity)
        all_members.extend(nested_members)

        # call get_entity_members repetitively till you reach a stage where 
        # there are no nested members
        while nested_members:
            curr_nested_members = []
            for member_type, member_ref, member_name in nested_members:
                if member_type == 'class':
                    # drill nested members only in a class
                    members = self.get_entity_members(member_ref)
                    curr_nested_members.extend(members)
            nested_members = curr_nested_members
            all_members.extend(nested_members)

        return all_members

class TestDocstr4(object):

    @classmethod
    def test_docstr(self, entity):
        all_members = ModStruct1(entity).get_all_members()

        non_docstr_entities = defaultdict(list)

        # get all the nested members of root entity
        for member_data in all_members:
            member_type, member_ref, member_name = member_data
            # consolidate members based on type
            if not has_docstr(member_ref):
                non_docstr_entities[member_type].append(member_name)

        if non_docstr_entities.keys():
            errors = []
            # create error string
            for entity_type, refs in non_docstr_entities.iteritems():
                for refname in refs:
                    errors.append('%s: %s does not have docstr' % (entity_type,
                                                                   refname))
            raise NoDocstrError('\n' + '\n'.join(errors))
        return True

TestDocstr4.test_docstr(mod1)
# Out:
# ---------------------------------------------------------------------------
# NoDocstrError                             Traceback (most recent call last)
# <ipython-input-6-5d5d470753e4> in <module>()
#      83         return True
#      84
# ---> 85 TestDocstr4.test_docstr(mod1)
#
# <ipython-input-6-5d5d470753e4> in test_docstr(self, entity)
#      80                     errors.append('%s: %s does not have docstr' % (entity_type,
#      81                                                                    refname))
# ---> 82             raise NoDocstrError('\n' + '\n'.join(errors))
#      83         return True
#      84
#
# NoDocstrError:
# function: mod1.main does not have docstr
# class: mod1.SpecFile does not have docstr
# class: SpecFile.DynamicSection does not have docstr
# class: SpecFile.Section does not have docstr
# class: SpecFile.Section1 does not have docstr
# class: SpecFile.Section2 does not have docstr
# class: SpecFile.StaticSection does not have docstr
# module: mod1 does not have docstr
# method: DynamicSection.__init__ does not have docstr
# method: DynamicSection.validate does not have docstr
# method: Section.__init__ does not have docstr
# method: Section.validate does not have docstr
# method: Section1.__init__ does not have docstr
# method: Section1.validate does not have docstr
# method: Section2.__init__ does not have docstr
# method: Section2.validate does not have docstr
# method: StaticSection.__init__ does not have docstr
# method: StaticSection.validate does not have docstr

# %% [markdown]
# Although the above output is less ambiguous - as each function/method name is prefixed by its parent, it still has the limitation of having entity name prefixed only by its immediate parent and not right from the top of the ancestry. For example, StaticSection.validate should ideally be mod1.SpecFile.StaticSection.validate - this means that we need the fully qualified name of each entity.
#
# If we were using Python 3.3 - we would have no need to proceed further because as per <a href="http://stackoverflow.com/questions/2020014/get-fully-qualified-class-name-of-an-object-in-python" target="_blank">this SO answer</a> an additional attribute \_\_qualname\_\_ has been added to functions and classes in Python 3.3 - which would give you the fully qualified name.
#
# Python tutor gives online shell for executing Python 2.7/3.3 code - <a href="http://goo.gl/BZn9Kp" target="_blank">this link</a> runs a qualname checking code snippet in Python 3.3 - try running it in 2.7 also to see the difference.
#
# Fortunately I am using Python 2.7.3 - so we march forth :)
#
# We need to make the following changes:
#
# 1. Find out the fully qualified name of each member.
#
# To do this we will have to traverse all the members of the module and for every member his name will be - parent_name.member. We can use the following pseudocode to achieve this (have made the pseudocode somewhat Python specific to keep the context):

# %% [raw]
# # module_members - all the members of a module (even the nested ones)
#
# for entity in module_members:
#     id_entity = id(entity) # the Python id function
#     id_parent = id(entity.parent) # pseudocode assumption - id returns None for a module's parent
#     entity_name = entity.__name__
#
#     if id_parent is not None:
#         parent_name = id_name_map[id_parent]
#         entity_name = parent_name + '.' + entity_name
#
#     id_name_map[id_entity] = entity_name
#
# return entity_name

# %% [markdown]
# It is implied that no matter what the base_entity is (entity for which we are testing docstrings) - we have to traverse the entire module tree because the fully qualified name starts from the topmost level. Hence we have to add these methods to the ModStruct class:
#
# 1. build_id_name_map - implement above algorithm.
# 2. get_entity_name - when the entire id_name map is built, looking up entity name is as simple as passing in its id.
# 3. extract_entity_members - once we've got all the members of the module and for each member ran the get_entity_name and updated its name, we need to extract out members which the user asked for i.e. if the user passed in mod1.SpecFile.Section - we should return only the members of the mod1.SpecFile.Section tree.
#
# Enough chit-chat - here's the evolved t5.py:

# %%
# %load t5.py

# %%
from nbcommon import *
import mod1

import inspect
import sys
from collections import defaultdict

class ModStruct2(object):
    """ Return a data structure representing all members of the passed
    entity """

    def __init__(self, base_entity):
        self.base_entity_type = get_entity_type(base_entity)
        self.base_entity = base_entity
        self.base_module = base_entity
        self.id_name_map = {}
        self.all_members = []
        if self.base_entity_type != 'module':
            # if entity_type is class - know which module it belongs to
            self.base_module = sys.modules[base_entity.__module__]

    def get_entity_name(self, entity):
        """ Return fully qualified name of entity """
        return self.id_name_map.get(id(entity), None)

    def build_id_name_map(self, entity, parent=None):
        """ Map entity id to its fully qualified name """
        entity_name = entity.__name__
        if not parent is None:
            id_parent = id(parent)
            if id_parent in self.id_name_map:
                parent_name = self.id_name_map[id_parent]
                entity_name = '.'.join([parent_name, entity.__name__])
        self.id_name_map[id(entity)] = entity_name

    def extract_entity_members(self):
        """ From all the members extract out member tree of the base 
        entity """
        base_entity_name = self.get_entity_name(self.base_entity)

        base_entity_members = []
        for member in self.all_members:
            if member['name'].startswith(base_entity_name):
                base_entity_members.append(member)
        self.base_entity_members = base_entity_members

    def get_entity_members(self, entity):
        """ Get first level members of the passed entity """
        members = []
        for member in inspect.getmembers(entity):
            ref = member[1]
            # member has to be of supported entity type
            try:
                ref_type = get_entity_type(ref)
            except ValueError:
                continue
            # member has to be defined in base module
            if ref.__module__ != self.base_module.__name__: continue
            # valid member - append member reference, type and name to the 
            # member  list
            members.append({'type': ref_type, 'ref': ref, 'parent': entity})
            self.build_id_name_map(ref, entity)
        return members

    def get_all_members(self):
        """ Get all the members (nested also) of the passed entity """

        # add base module as the first element
        all_members = [{'type': 'module',
                        'ref': self.base_module, 'parent_ref': None}]

        # add base module as first entry to id_name_map - root of all names
        self.build_id_name_map(self.base_module, None)

        # get first level members of the module
        nested_members = self.get_entity_members(self.base_module)
        all_members.extend(nested_members)

        # call get_entity_members repetitively till you reach a stage where 
        # there are no nested members
        while nested_members:
            curr_nested_members = []
            # for member_type, member_ref, member_name in nested_members:
            for member_data in nested_members:
                if member_data['type'] == 'class':
                    # drill nested members only in a class
                    members = self.get_entity_members(member_data['ref'])
                    curr_nested_members.extend(members)
            nested_members = curr_nested_members
            all_members.extend(nested_members)

        # set fully qualified name of all members
        for member in all_members:
            member['name'] = self.get_entity_name(member['ref'])

        self.all_members = all_members

        # if entity is not a module extract the entity members from all 
        # members
        if self.base_entity_type == 'module':
            return all_members

        self.extract_entity_members()
        return self.base_entity_members

class TestDocstr5(object):

    @classmethod
    def test_docstr(self, entity):
        all_members = ModStruct2(entity).get_all_members()

        non_docstr_entities = defaultdict(list)

        # get all the nested members of root entity
        for member_data in all_members:
            # consolidate members based on type
            if not has_docstr(member_data['ref']):
                member_name = member_data['name']
                non_docstr_entities[member_data['type']].append(member_name)

        if non_docstr_entities.keys():
            errors = []
            # create error string
            for entity_type, refs in non_docstr_entities.iteritems():
                for refname in refs:
                    errors.append('%s: %s does not have docstr' % (entity_type,
                                                                   refname))
            raise NoDocstrError('\n' + '\n'.join(errors))
        return True


TestDocstr5.test_docstr(mod1.SpecFile)
# Out:
# ---------------------------------------------------------------------------
# NoDocstrError                             Traceback (most recent call last)
# <ipython-input-7-a7ca751f3389> in <module>()
#     130
#     131
# --> 132 TestDocstr5.test_docstr(mod1.SpecFile)
#
# <ipython-input-7-a7ca751f3389> in test_docstr(self, entity)
#     126                     errors.append('%s: %s does not have docstr' % (entity_type,
#     127                                                                    refname))
# --> 128             raise NoDocstrError('\n' + '\n'.join(errors))
#     129         return True
#     130
#
# NoDocstrError:
# class: mod1.SpecFile does not have docstr
# class: mod1.SpecFile.DynamicSection does not have docstr
# class: mod1.SpecFile.Section does not have docstr
# class: mod1.SpecFile.Section1 does not have docstr
# class: mod1.SpecFile.Section2 does not have docstr
# class: mod1.SpecFile.StaticSection does not have docstr
# method: mod1.SpecFile.DynamicSection.__init__ does not have docstr
# method: mod1.SpecFile.DynamicSection.validate does not have docstr
# method: mod1.SpecFile.Section.__init__ does not have docstr
# method: mod1.SpecFile.Section.validate does not have docstr
# method: mod1.SpecFile.Section1.__init__ does not have docstr
# method: mod1.SpecFile.Section1.validate does not have docstr
# method: mod1.SpecFile.Section2.__init__ does not have docstr
# method: mod1.SpecFile.Section2.validate does not have docstr
# method: mod1.SpecFile.StaticSection.__init__ does not have docstr
# method: mod1.SpecFile.StaticSection.validate does not have docstr

# %% [markdown]
# So that's about it. Now we get names like mod1.SpecFile.StaticSection.validate which is the fully qualified name of the method. For me, this was a fun exercise to incrementally add features to the code. Hope you also found it useful.
#
# Although this is outside the scope of this post, we can do a few more tweaks to make ModStruct class usage more intuitive:
#
# 1. Rename get_all_members to a shorter, more generic name like - inspect_all.
# <pre>
# m = ModStruct(mod1)
# m.inspect_all()
# </pre>
#
# 2. Update inspect_all to return he following data structure rather than a list of dicts:
# <pre>
# m.inspect_all()
# {
#   'name': full_name_of_base_entity,
#   'ref': ref_of_base_entity,
#   'type': type_of_base_entity,
#   'members': [{'name': member_name, 'type': member_type, 'ref': member_ref},...]
# }
# </pre>
#
# 3. Make inspect_all take a flag - categorize - which categorizes members into classes, functions, etc.:
#
# <pre>
# m.inspect_all(categorize=True)
# {
#   'name': full_name_of_base_entity,
#   'ref': ref_of_base_entity,
#   'type': type_of_base_entity,
#   'members': {
#     'class': {'Class1': {'name': class1_full_name,
#                          'ref': class1_ref,
#                          'members': {'class1_method_1': {'ref': class1_method1_ref}, ...},
#     'function': {'func1': {'ref': func1_ref}, ....}
#   }
# }
# </pre>
#
# If someone passes in module as base_entity - 'class' will contain all the classes. But if a class is passed as a base entity, 'class' will contain only the classes nested under the base_entity class.
#
# 4. There is a cinch in the armor of __t5.py__ - which causes the program to fail for a certain class of inputs. See if you can find that bug. As the bug covers an interesting area which requires a blog post of its own, I will bring it up in my next post.
#
# As mentioned earlier all of the above t\*.py files hosted at: https://github.com/saurabh-hirani/talks/tree/master/docstrings
